# %% [markdown]
# ## package 불러오기

# %%
import numpy as np

from PIL import Image

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ---

# %% [markdown]
# ## 이미지 파일 열기

# %% [markdown]
# opencv로도 열수 있지만, shape 순서가 바뀔 때도 있어서 PIL로 여는 것을 개인적으로 선호

# %%
path = "source/dog.jpg"
image_pil = Image.open(path)
image = np.array(image_pil)

# %% [markdown]
# ---

# %% [markdown]
# ## 이미지 들여다 보기

# %%
image.shape
# Out:
# (620, 620, 3)

# %%
np.min(image), np.max(image)
# Out:
# (0, 255)

# %% [markdown]
# 이미지를 열기 전에 shape 및 min, max를 통해서 이미지의 range 확인 필요

# %% [markdown]
# ___

# %% [markdown]
# ## 그래프로 시각화 하기

# %%
plt.hist(image.ravel(), 256, [0,256]) #ravel: 쫙 펼치기
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 그림 나타내기

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# ---
# ## 이미지 흑백으로 열기

# %%
path
# Out:
# 'source/dog.jpg'

# %%
image_pil = Image.open(path).convert("L")
image_bw =np.array(image_pil)

# %%
image_bw.shape
# Out:
# (620, 620)

# %% [markdown]
# ---
# ## 흑백 이미지 열기

# %%
# 2개의 차원일 때는 gray scale로 열림
plt.imshow(image_bw, 'gray')
plt.show()

# %% [markdown]
# ---
# ### 다른 색상으로 cmap 표현하기

# %% [markdown]
# ### gray scale

# %%
image_bw.shape
# Out:
# (620, 620)

# %% [markdown]
# ---

# %% [markdown]
# ### RdBu

# %%
plt.imshow(image_bw, 'RdBu')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### jet

# %%
plt.imshow(image_bw, 'jet')
plt.show()

# %% [markdown]
# ---
# ## Colorbar 추가하기

# %%
plt.imshow(image_bw, 'jet')
plt.colorbar()
plt.show()

# %% [markdown]
# ---
# ## 이미지 설정

# %% [markdown]
# 이미지 보기 사이즈 조절

# %%
plt.figure(figsize=(10,5))
plt.imshow(image)
plt.show()

# %% [markdown]
# ---
# ## 이미지에 제목 추가

# %%
plt.title('Dog')
plt.imshow(image)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 두번째 이미지 열기

# %%
cat_path = "source/cat.jpg"
cat_pil = Image.open(cat_path)
cat_image = np.array(cat_pil)

# %%
plt.imshow(cat_image)
plt.show()

# %% [markdown]
# ---
# ## 두번쨰 이미지를 첫번째 이미지 모양에 맞추기

# %%
cat_image.shape
# Out:
# (467, 700, 3)

# %%
image.shape, cat_image.shape
# Out:
# ((620, 620, 3), (467, 700, 3))

# %% [markdown]
# ---

# %% [markdown]
# ## 두번째 이미지 합치기 위한 준비

# %%
# !pip install opencv-python # opencv가 설치 안 되어있으면 설치
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.2.0.32-cp37-cp37m-win_amd64.whl (33.0 MB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\user\appdata\local\continuum\anaconda3\lib\site-packages (from opencv-python) (1.18.1)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.2.0.32

# %%
import cv2

# %%
dog_image = cv2.resize(image, (700, 467))
dog_image.shape, cat_image.shape
# Out:
# ((467, 700, 3), (467, 700, 3))

# %% [markdown]
# ---

# %% [markdown]
# ## Image 합치기

# %%
plt.imshow(dog_image)
plt.imshow(cat_image, alpha = 0.5) #alpha: 투명도. 고양이가덮어쓰므로 투명도 설정
plt.show()

# %% [markdown]
# ---
# # Subplot

# %%
plt.figure(figsize=(10,10))

plt.subplot(221)
plt.imshow(dog_image)

plt.subplot(222)
plt.imshow(image_bw, 'gray')

plt.subplot(223)
plt.imshow(cat_image)
plt.show()
